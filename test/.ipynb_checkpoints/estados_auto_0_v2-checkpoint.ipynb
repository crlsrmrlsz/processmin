# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_tramites_proc_X = pd.read_parquet('./data/tramita/tramites_autoconsumo.parquet')

# %%
df_tramites_proc_X.head()
# Out:
#         id_exp      dni   nif      fecha_alta_exp fecha_registro_exp  \
# 45875  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45876  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45877  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45878  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45879  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
#
#       codine_provincia codine_municipio codine municipio    provincia  ...  \
# 45875               13              064  13064   Poblete  Ciudad Real  ...
# 45876               13              064  13064   Poblete  Ciudad Real  ...
# 45877               13              064  13064   Poblete  Ciudad Real  ...
# 45878               13              064  13064   Poblete  Ciudad Real  ...
# 45879               13              064  13064   Poblete  Ciudad Real  ...
#
#       siaci                      consejeria_proc  \
# 45875  SLPT  Consejeria de desarrollo sostenible
# 45876  SLPT  Consejeria de desarrollo sostenible
# 45877  SLPT  Consejeria de desarrollo sostenible
# 45878  SLPT  Consejeria de desarrollo sostenible
# 45879  SLPT  Consejeria de desarrollo sostenible
#
#                               org_instructor_proc es_telematica  \
# 45875  Direccion general de transicion energetica          True
# 45876  Direccion general de transicion energetica          True
# 45877  Direccion general de transicion energetica          True
# 45878  Direccion general de transicion energetica          True
# 45879  Direccion general de transicion energetica          True
#
#                                             desc_tramite       fecha_tramite  \
# 45875                              Registro de solicitud 2021-12-23 00:00:00
# 45876                   1-1-Presentación de la solicitud 2022-02-09 09:07:17
# 45877                   10-1-Requerimiento documentación 2022-10-14 09:44:23
# 45878                       30-1-Evaluación de Solicitud 2022-10-27 08:04:51
# 45879  42-1-Propuesta Resolución Estimatoria de Conce... 2022-10-27 08:14:55
#
#        num_tramite cod_procedimiento orden_tramite  es_inicial
# 45875            0             884.0             0       False
# 45876            1             884.0             1        True
# 45877           10             884.0             2       False
# 45878           30             884.0             3       False
# 45879           42             884.0             4       False
#
# [5 rows x 23 columns]

# %%
columns_estados = ['id_exp','desc_tramite','fecha_tramite']
df_tramites_proc_X_simple = df_tramites_proc_X[columns_estados]
df_tramites_proc_X_simple = df_tramites_proc_X_simple.rename(columns={'fecha_tramite': 'fecha'})
df_tramites_proc_X_simple['fecha'] = df_tramites_proc_X_simple['fecha'].dt.date
df_tramites_proc_X_simple.head()
# Out:
#         id_exp                                       desc_tramite       fecha
# 45875  1127895                              Registro de solicitud  2021-12-23
# 45876  1127895                   1-1-Presentación de la solicitud  2022-02-09
# 45877  1127895                   10-1-Requerimiento documentación  2022-10-14
# 45878  1127895                       30-1-Evaluación de Solicitud  2022-10-27
# 45879  1127895  42-1-Propuesta Resolución Estimatoria de Conce...  2022-10-27

# %%
#asignamos fecha como nueva columna, quitándonos la hora
# df_estados_proc_X = df_estados_proc_X.assign(fecha=df_estados_proc_X['fecha_tramite'].dt.date)
# df_estados_proc_X.drop('fecha_tramite', axis = 1, inplace = True)
# df_estados_proc_X.head()
# Here are the possible ways to add a new column to a DataFrame that is calculated from another original column of the same DataFrame:

# Assign: df['new_column'] = df['original_column'] * 2
# Apply: df['new_column'] = df.apply(lambda x: x['original_column'] * 2, axis=1)
# Map: df['new_column'] = df['original_column'].map(lambda x: x * 2)
# Assign with conditional: df['new_column'] = np.where(df['original_column'] > 0, df['original_column'] * 2, 0)
# Using pandas' built-in functions: df['new_column'] = df['original_column'].rolling(window=3).mean()
# Using pandas' groupby: df.groupby('group_column')['original_column'].sum().reset_index(name='new_column')

# %% [markdown]
# # Número de expedientes en estado x por fecha, forward fill

# %%
df = df_tramites_proc_X_simple

# %% [markdown]
# ## quitar duplicados

# %%
duplicates = df[df.duplicated(subset=['id_exp', 'fecha', 'desc_tramite'], keep=False)]
duplicates
# Out:
#           id_exp                                       desc_tramite  \
# 731972   1256497                       30-1-Evaluación de Solicitud
# 731973   1256497  42-1-Propuesta Resolución Estimatoria de Conce...
# 731975   1256497                       30-1-Evaluación de Solicitud
# 731976   1256497  42-1-Propuesta Resolución Estimatoria de Conce...
# 6496786  1239794                       50-1-Resolución de Concesión
# 6496787  1239794                       50-1-Resolución de Concesión
# 7234997  1171327  51-1-Resolución desestimatoria - Incumple Requ...
# 7234998  1171327  51-1-Resolución desestimatoria - Incumple Requ...
# 7756529  1164657                       50-1-Resolución de Concesión
# 7756532  1164657                       50-1-Resolución de Concesión
#
#               fecha
# 731972   2024-07-18
# 731973   2024-07-18
# 731975   2024-07-18
# 731976   2024-07-18
# 6496786  2024-07-18
# 6496787  2024-07-18
# 7234997  2023-10-23
# 7234998  2023-10-23
# 7756529  2023-12-01
# 7756532  2023-12-01

# %%
# drop duplicates
df = df.drop_duplicates(
    subset=['id_exp', 'fecha', 'desc_tramite'], 
    keep='last'
)

# %% [markdown]
# ## quitar 15500 expedientes con finales "presentacion solicitud"

# %%
final_states = df.sort_values(['id_exp', 'fecha']).groupby('id_exp').last().reset_index()
# si se filtra sort_values('fecha') sale mal, hay algo que falla al ordenar
final_states
# Out:
#         id_exp                                   desc_tramite       fecha
# 0      1083865                              287-1-Seguimiento  2023-07-04
# 1      1083888                              287-1-Seguimiento  2023-05-04
# 2      1083890  70-1-Presentación Documentación Justificativa  2024-04-05
# 3      1083903                              287-1-Seguimiento  2023-04-03
# 4      1083907                              287-1-Seguimiento  2023-04-03
# ...        ...                                            ...         ...
# 25840  1736598               1-1-Presentación de la solicitud  2024-01-18
# 25841  1738774               1-1-Presentación de la solicitud  2024-01-24
# 25842  1853399               1-1-Presentación de la solicitud  2024-02-22
# 25843  1861916               1-1-Presentación de la solicitud  2024-03-06
# 25844  1956447                   50-1-Resolución de Concesión  2024-07-18
#
# [25845 rows x 3 columns]

# %%
final_states[final_states['id_exp']==1084489]
# Out:
#      id_exp       desc_tramite       fecha
# 23  1084489  287-1-Seguimiento  2023-05-09

# %%
final_states_grp = final_states.groupby('desc_tramite').size()
final_states_grp
# Out:
# desc_tramite
# 1-1-Presentación de la solicitud                                   15152
# 10-1-Requerimiento documentación                                     397
# 10-2-Requerimiento documentación                                      92
# 100-1-Fin de procedimiento                                           682
# 152-1-Propuesta de Resolucion Desistimiento                           23
# 278-1-Resolución de Pérdida de Derecho al Cobro Total                  3
# 283-1-Propuesta Resolución de Pérdida de Derecho al Cobro Total        1
# 286-1-Presentación Solicitud Desistimiento                             1
# 287-1-Seguimiento                                                    851
# 30-1-Evaluación de Solicitud                                           6
# 309-1-Lista de Reserva Provisional por Insuficiencia de Credito        2
# 41-1-Propuesta Resolución Desestimatoria - Incumple Requisitos        21
# 42-1-Propuesta Resolución Estimatoria de Concesión                   949
# 50-1-Resolución de Concesión                                        3860
# 51-1-Resolución desestimatoria - Incumple Requisitos                 403
# 52-1-Resolucion Desistimiento                                         35
# 70-1-Presentación Documentación Justificativa                       3303
# 82-1-Pago Total                                                       64
# dtype: int64

# %%
id_exp_to_remove = final_states.loc[(final_states['desc_tramite'] =='1-1-Presentación de la solicitud'), "id_exp"].unique()
id_exp_to_remove
# Out:
# array([1088250, 1094269, 1094633, ..., 1738774, 1853399, 1861916],
#       dtype=uint32)

# %%
len(id_exp_to_remove)
# Out:
# 15152

# %%
# Filter out rows with those `id_exp` values
filtered_df = df[~df["id_exp"].isin(id_exp_to_remove)]

# %%
len(filtered_df.id_exp.unique())
# Out:
# 10693

# %% [markdown]
# ## fill forward

# %%
# puede haber varios cambios de estado es 1 día, hay que hacer una lista para cada expediente-dia de todos los estados por los que ha pasado
df = (
    filtered_df.reset_index()  # Reset index to access columns
    .sort_values(['id_exp', 'fecha'])  # Ensure proper sorting
    .groupby(['id_exp', 'fecha'])['desc_tramite']
    .agg(list)  # Combine states into a list
    .reset_index()
    .set_index(['id_exp', 'fecha'])  # Restore MultiIndex
)
df
# Out:
#                                                          desc_tramite
# id_exp  fecha
# 1083865 2021-12-22                            [Registro de solicitud]
#         2022-02-04                 [1-1-Presentación de la solicitud]
#         2022-04-19                 [10-1-Requerimiento documentación]
#         2022-05-04                     [30-1-Evaluación de Solicitud]
#         2022-06-08  [42-1-Propuesta Resolución Estimatoria de Conc...
# ...                                                               ...
# 1670837 2024-08-12                 [10-1-Requerimiento documentación]
# 1956447 2022-05-02                            [Registro de solicitud]
#         2024-06-21  [1-1-Presentación de la solicitud, 10-1-Requer...
#         2024-06-26  [30-1-Evaluación de Solicitud, 42-1-Propuesta ...
#         2024-07-18                     [50-1-Resolución de Concesión]
#
# [54262 rows x 1 columns]

# %%
df.loc[df.index.get_level_values(0) == 1084489]
# Out:
#                                                          desc_tramite
# id_exp  fecha
# 1084489 2021-12-22                            [Registro de solicitud]
#         2022-02-04                 [1-1-Presentación de la solicitud]
#         2022-06-10  [30-1-Evaluación de Solicitud, 42-1-Propuesta ...
#         2022-08-10                     [50-1-Resolución de Concesión]
#         2023-01-25    [70-1-Presentación Documentación Justificativa]
#         2023-04-24  [30-2-Evaluación de justificación, 82-1-Pago T...
#         2023-05-09                                [287-1-Seguimiento]

# %%
timeline = pd.date_range(df.index.get_level_values('fecha').min(),
                         df.index.get_level_values('fecha').max())
timeline
# Out:
# DatetimeIndex(['2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25',
#                '2021-12-26', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31',
#                ...
#                '2024-08-17', '2024-08-18', '2024-08-19', '2024-08-20',
#                '2024-08-21', '2024-08-22', '2024-08-23', '2024-08-24',
#                '2024-08-25', '2024-08-26'],
#               dtype='datetime64[ns]', length=979, freq='D')

# %%
# Create a MultiIndex with all combinations of id_exp and timeline
multi_index = pd.MultiIndex.from_product(
    [df.index.levels[0], timeline], names=['id_exp', 'fecha']
)
multi_index
# Out:
# MultiIndex([(1083865, '2021-12-22'),
#             (1083865, '2021-12-23'),
#             (1083865, '2021-12-24'),
#             (1083865, '2021-12-25'),
#             (1083865, '2021-12-26'),
#             (1083865, '2021-12-27'),
#             (1083865, '2021-12-28'),
#             (1083865, '2021-12-29'),
#             (1083865, '2021-12-30'),
#             (1083865, '2021-12-31'),
#             ...
#             (1956447, '2024-08-17'),
#             (1956447, '2024-08-18'),
#             (1956447, '2024-08-19'),
#             (1956447, '2024-08-20'),
#             (1956447, '2024-08-21'),
#             (1956447, '2024-08-22'),
#             (1956447, '2024-08-23'),
#             (1956447, '2024-08-24'),
#             (1956447, '2024-08-25'),
#             (1956447, '2024-08-26')],
#            names=['id_exp', 'fecha'], length=10468447)

# %%
print(df.index.is_unique)
# Out:
# True

# %%
# Reindex to this complete MultiIndex
df = df.reindex(multi_index)
df

# 1. Aligning Data to a New Index
# reindex allows you to change the index or column labels of a DataFrame or Series to match a new index or set of labels. 
# This is particularly useful for aligning data across datasets.

# import pandas as pd

# data = {'A': [1, 2, 3]}
# df = pd.DataFrame(data, index=['a', 'b', 'c'])

# # Aligning to a new index
# new_index = ['a', 'b', 'd', 'e']
# df_reindexed = df.reindex(new_index)

# print(df_reindexed)

#      A
# a  1.0
# b  2.0
# d  NaN
# e  NaN


# 2. Interpolating Data Over a Time Index
# In time-series data, reindex is often used to fill gaps or align data to a regular frequency.
# import pandas as pd
# date_range = pd.date_range('2023-01-01', '2023-01-05')
# data = {'value': [10, 15, 20]}
# df = pd.DataFrame(data, index=pd.to_datetime(['2023-01-01', '2023-01-03', '2023-01-05']))

# # Reindex to a daily frequency
# df_reindexed = df.reindex(date_range).interpolate()

# print(df_reindexed)

#            value
# 2023-01-01   10.0
# 2023-01-02   12.5
# 2023-01-03   15.0
# 2023-01-04   17.5
# 2023-01-05   20.0
# Out:
#                                desc_tramite
# id_exp  fecha
# 1083865 2021-12-22  [Registro de solicitud]
#         2021-12-23                      NaN
#         2021-12-24                      NaN
#         2021-12-25                      NaN
#         2021-12-26                      NaN
# ...                                     ...
# 1956447 2024-08-22                      NaN
#         2024-08-23                      NaN
#         2024-08-24                      NaN
#         2024-08-25                      NaN
#         2024-08-26                      NaN
#
# [10468447 rows x 1 columns]

# %%
df[df['desc_tramite'].notna()]
# Out:
#                                                          desc_tramite
# id_exp  fecha
# 1083865 2021-12-22                            [Registro de solicitud]
#         2022-02-04                 [1-1-Presentación de la solicitud]
#         2022-04-19                 [10-1-Requerimiento documentación]
#         2022-05-04                     [30-1-Evaluación de Solicitud]
#         2022-06-08  [42-1-Propuesta Resolución Estimatoria de Conc...
# ...                                                               ...
# 1670837 2024-08-12                 [10-1-Requerimiento documentación]
# 1956447 2022-05-02                            [Registro de solicitud]
#         2024-06-21  [1-1-Presentación de la solicitud, 10-1-Requer...
#         2024-06-26  [30-1-Evaluación de Solicitud, 42-1-Propuesta ...
#         2024-07-18                     [50-1-Resolución de Concesión]
#
# [54262 rows x 1 columns]

# %%
# df_estados_proc_X_reindexed['num_tramite'] = (
#     df_estados_proc_X_reindexed['num_tramite']
#     .groupby(level=0)  # Group by `id_exp`
#     .apply(lambda group: group.ffill())  # Forward-fill lists
# )
df['desc_tramite'] = df['desc_tramite'].groupby(level=0).ffill()
df
# Out:
#                                       desc_tramite
# id_exp  fecha
# 1083865 2021-12-22         [Registro de solicitud]
#         2021-12-23         [Registro de solicitud]
#         2021-12-24         [Registro de solicitud]
#         2021-12-25         [Registro de solicitud]
#         2021-12-26         [Registro de solicitud]
# ...                                            ...
# 1956447 2024-08-22  [50-1-Resolución de Concesión]
#         2024-08-23  [50-1-Resolución de Concesión]
#         2024-08-24  [50-1-Resolución de Concesión]
#         2024-08-25  [50-1-Resolución de Concesión]
#         2024-08-26  [50-1-Resolución de Concesión]
#
# [10468447 rows x 1 columns]

# %%
df.loc[df.index.get_level_values(0) == 1084489]
# Out:
#                                desc_tramite
# id_exp  fecha
# 1084489 2021-12-22  [Registro de solicitud]
#         2021-12-23  [Registro de solicitud]
#         2021-12-24  [Registro de solicitud]
#         2021-12-25  [Registro de solicitud]
#         2021-12-26  [Registro de solicitud]
# ...                                     ...
#         2024-08-22      [287-1-Seguimiento]
#         2024-08-23      [287-1-Seguimiento]
#         2024-08-24      [287-1-Seguimiento]
#         2024-08-25      [287-1-Seguimiento]
#         2024-08-26      [287-1-Seguimiento]
#
# [979 rows x 1 columns]

# %%
df = df.explode('desc_tramite')
df
# Out:
#                                     desc_tramite
# id_exp  fecha
# 1083865 2021-12-22         Registro de solicitud
#         2021-12-23         Registro de solicitud
#         2021-12-24         Registro de solicitud
#         2021-12-25         Registro de solicitud
#         2021-12-26         Registro de solicitud
# ...                                          ...
# 1956447 2024-08-22  50-1-Resolución de Concesión
#         2024-08-23  50-1-Resolución de Concesión
#         2024-08-24  50-1-Resolución de Concesión
#         2024-08-25  50-1-Resolución de Concesión
#         2024-08-26  50-1-Resolución de Concesión
#
# [11671675 rows x 1 columns]

# %%
df.loc[df.index.get_level_values(0) == 1084489]
# Out:
#                              desc_tramite
# id_exp  fecha
# 1084489 2021-12-22  Registro de solicitud
#         2021-12-23  Registro de solicitud
#         2021-12-24  Registro de solicitud
#         2021-12-25  Registro de solicitud
#         2021-12-26  Registro de solicitud
# ...                                   ...
#         2024-08-22      287-1-Seguimiento
#         2024-08-23      287-1-Seguimiento
#         2024-08-24      287-1-Seguimiento
#         2024-08-25      287-1-Seguimiento
#         2024-08-26      287-1-Seguimiento
#
# [1055 rows x 1 columns]

# %%
result = (
    df.reset_index()
    .groupby(['fecha', 'desc_tramite'])
    .size()
    .unstack(fill_value=0)
)
result.head()
# Out:
# desc_tramite  1-1-Presentación de la solicitud  \
# fecha
# 2021-12-22                                   0
# 2021-12-23                                   0
# 2021-12-24                                   0
# 2021-12-25                                   0
# 2021-12-26                                   0
#
# desc_tramite  10-1-Requerimiento documentación  \
# fecha
# 2021-12-22                                   0
# 2021-12-23                                   0
# 2021-12-24                                   0
# 2021-12-25                                   0
# 2021-12-26                                   0
#
# desc_tramite  10-2-Requerimiento documentación  100-1-Fin de procedimiento  \
# fecha
# 2021-12-22                                   0                           0
# 2021-12-23                                   0                           0
# 2021-12-24                                   0                           0
# 2021-12-25                                   0                           0
# 2021-12-26                                   0                           0
#
# desc_tramite  152-1-Propuesta de Resolucion Desistimiento  \
# fecha
# 2021-12-22                                              0
# 2021-12-23                                              0
# 2021-12-24                                              0
# 2021-12-25                                              0
# 2021-12-26                                              0
#
# desc_tramite  21-1-Presentación de Renuncia  \
# fecha
# 2021-12-22                                0
# 2021-12-23                                0
# 2021-12-24                                0
# 2021-12-25                                0
# 2021-12-26                                0
#
# desc_tramite  278-1-Resolución de Pérdida de Derecho al Cobro Total  \
# fecha
# 2021-12-22                                                    0
# 2021-12-23                                                    0
# 2021-12-24                                                    0
# 2021-12-25                                                    0
# 2021-12-26                                                    0
#
# desc_tramite  278-2-Resolucion de perdida parcial de derecho al cobro  \
# fecha
# 2021-12-22                                                    0
# 2021-12-23                                                    0
# 2021-12-24                                                    0
# 2021-12-25                                                    0
# 2021-12-26                                                    0
#
# desc_tramite  283-1-Propuesta Resolución de Pérdida de Derecho al Cobro Total  \
# fecha
# 2021-12-22                                                    0
# 2021-12-23                                                    0
# 2021-12-24                                                    0
# 2021-12-25                                                    0
# 2021-12-26                                                    0
#
# desc_tramite  286-1-Presentación Solicitud Desistimiento  ...  \
# fecha                                                     ...
# 2021-12-22                                             0  ...
# 2021-12-23                                             0  ...
# 2021-12-24                                             0  ...
# 2021-12-25                                             0  ...
# 2021-12-26                                             0  ...
#
# desc_tramite  42-3-Propuesta Resolución Estimatoria Abono Pérdida Parcial  \
# fecha
# 2021-12-22                                                    0
# 2021-12-23                                                    0
# 2021-12-24                                                    0
# 2021-12-25                                                    0
# 2021-12-26                                                    0
#
# desc_tramite  50-1-Resolución de Concesión  \
# fecha
# 2021-12-22                               0
# 2021-12-23                               0
# 2021-12-24                               0
# 2021-12-25                               0
# 2021-12-26                               0
#
# desc_tramite  51-1-Resolución desestimatoria - Incumple Requisitos  \
# fecha
# 2021-12-22                                                    0
# 2021-12-23                                                    0
# 2021-12-24                                                    0
# 2021-12-25                                                    0
# 2021-12-26                                                    0
#
# desc_tramite  52-1-Resolucion Desistimiento  \
# fecha
# 2021-12-22                                0
# 2021-12-23                                0
# 2021-12-24                                0
# 2021-12-25                                0
# 2021-12-26                                0
#
# desc_tramite  53-1-Resolución Aceptación de Renuncia  \
# fecha
# 2021-12-22                                         0
# 2021-12-23                                         0
# 2021-12-24                                         0
# 2021-12-25                                         0
# 2021-12-26                                         0
#
# desc_tramite  70-1-Presentación Documentación Justificativa  82-1-Pago Total  \
# fecha
# 2021-12-22                                                0                0
# 2021-12-23                                                0                0
# 2021-12-24                                                0                0
# 2021-12-25                                                0                0
# 2021-12-26                                                0                0
#
# desc_tramite  82-2-Pago Parcial  90-1-Recurso de alzada  Registro de solicitud
# fecha
# 2021-12-22                    0                       0                    312
# 2021-12-23                    0                       0                    594
# 2021-12-24                    0                       0                    718
# 2021-12-25                    0                       0                    740
# 2021-12-26                    0                       0                    792
#
# [5 rows x 26 columns]

# %%
result.to_csv('./data/tramita/full/forwardfill_total.csv', encoding='utf-8',  sep=';', index = True, index_label='fecha')

# %%
column_states = ['Registro de solicitud',
                 '1-1-Presentación de la solicitud',
                #'287-1-Seguimiento',
                 '42-1-Propuesta Resolución Estimatoria de Concesión',
                ]
df_toplot = result[column_states]

# %%
# Plot
df_toplot.plot(kind="area", stacked=False, figsize=(12, 6), legend=dict(loc='upper right'))
plt.title("Acumulación estados en el tiempo")
plt.xlabel("Fecha")
plt.ylabel("Numero de expedientes")
plt.legend(title="Estados")
plt.show()

# %% [markdown]
# # Número de cambios por dia

# %%
# # tabla con el número total de cambios de estado , cada día, una columna por estado
# df_tramitesX_estados = df_tramitesX_estados.sort_values(by='fecha')
# # no hay valores para todas las fechas, habría que rellenar las fechas vacías.
# df_pivot_estados = df_tramitesX_estados.pivot_table(index='fecha', columns='num_tramite', aggfunc='size', fill_value=0)
# df_pivot_estados.tail()
