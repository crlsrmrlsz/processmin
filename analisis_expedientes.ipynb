# %%
import pandas as pd

# %% [markdown]
# # Analisis de expedientes

# %%
df_exp_autoconsumo = pd.read_parquet('./data/tramita/exp_autoconsumo.parquet')

# %%
df_exp_autoconsumo[df_exp_autoconsumo['id_exp']==1094269]
# Out:
#           id_exp  cod_procedimiento   dni    nif      fecha_alta_exp  \
# 1855649  1094269                884  <NA>  50977 2022-02-07 11:42:30
#
#         fecha_registro_exp codine_provincia codine_municipio codine  \
# 1855649         2021-12-22               13              034  13034
#
#            municipio    provincia unidad_tramitadora  \
# 1855649  Ciudad Real  Ciudad Real               <NA>
#
#                                        denom_procedimiento  \
# 1855649  SLPT - Ayudas para actuaciones de autoconsumo ...
#
#                                         desc_procedimiento siaci  \
# 1855649  Convocatoria de los programas de incentivos 4 ...  SLPT
#
#                              consejeria_proc  \
# 1855649  Consejeria de desarrollo sostenible
#
#                                 org_instructor_proc  es_telematica
# 1855649  Direccion general de transicion energetica           True

# %%
df_exp_autoconsumo[df_exp_autoconsumo['nif']==50977]
# Out:
#           id_exp  cod_procedimiento   dni    nif      fecha_alta_exp  \
# 199582   1167325                884  <NA>  50977 2022-02-15 13:01:25
# 215493   1167327                884  <NA>  50977 2022-02-15 13:02:43
# 357899   1165036                884  <NA>  50977 2022-02-11 08:45:25
# 1015148  1086307                884  <NA>  50977 2022-02-07 08:48:13
# 1046628  1086271                884  <NA>  50977 2022-02-07 08:40:46
# 1062739  1085779                884  <NA>  50977 2022-02-07 08:35:39
# 1078408  1087030                884  <NA>  50977 2022-02-07 09:25:48
# 1142135  1086315                884  <NA>  50977 2022-02-07 08:53:00
# 1157797  1086318                884  <NA>  50977 2022-02-07 08:55:17
# 1189299  1086291                884  <NA>  50977 2022-02-07 08:43:22
# 1189300  1086299                884  <NA>  50977 2022-02-07 08:45:25
# 1237185  1094633                884  <NA>  50977 2022-02-07 11:45:39
# 1252765  1087396                884  <NA>  50977 2022-02-07 09:32:26
# ...

# %% [markdown]
# # Análisis de trámites

# %%
df_tramitesX = pd.read_parquet('./data/tramita/tramites_autoconsumo.parquet')

# %%
df_tramitesX.head()
# Out:
#         id_exp      dni   nif      fecha_alta_exp fecha_registro_exp  \
# 45875  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45876  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45877  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45878  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
# 45879  1127895  1787973  <NA> 2022-02-09 09:07:17         2021-12-23
#
#       codine_provincia codine_municipio codine municipio    provincia  ...  \
# 45875               13              064  13064   Poblete  Ciudad Real  ...
# 45876               13              064  13064   Poblete  Ciudad Real  ...
# 45877               13              064  13064   Poblete  Ciudad Real  ...
# 45878               13              064  13064   Poblete  Ciudad Real  ...
# 45879               13              064  13064   Poblete  Ciudad Real  ...
#
#       siaci                      consejeria_proc  \
# ...

# %%
df_tramitesX[df_tramitesX['id_exp']==1088250]
# Out:
#           id_exp   dni    nif      fecha_alta_exp fecha_registro_exp  \
# 6265960  1088250  <NA>  50977 2022-02-07 09:50:23         2021-12-22
# 6265961  1088250  <NA>  50977 2022-02-07 09:50:23         2021-12-22
#
#         codine_provincia codine_municipio codine    municipio    provincia  \
# 6265960               13              034  13034  Ciudad Real  Ciudad Real
# 6265961               13              034  13034  Ciudad Real  Ciudad Real
#
#          ... siaci                      consejeria_proc  \
# 6265960  ...  SLPT  Consejeria de desarrollo sostenible
# 6265961  ...  SLPT  Consejeria de desarrollo sostenible
#
#                                 org_instructor_proc es_telematica  \
# 6265960  Direccion general de transicion energetica          True
# 6265961  Direccion general de transicion energetica          True
#
#                              desc_tramite       fecha_tramite  num_tramite  \
# 6265960             Registro de solicitud 2021-12-22 00:00:00            0
# ...

# %%
len(df_tramitesX[df_tramitesX['nif']==50977])
# Out:
# 96

# %%
df_tramites_nif = df_tramitesX[df_tramitesX['nif']==50977]
df_tramites_nif.groupby(['id_exp','fecha_registro_exp']).size()
# Out:
# id_exp   fecha_registro_exp
# 1085779  2021-12-22            5
# 1086271  2021-12-22            5
# 1086291  2021-12-22            5
# 1086299  2021-12-22            5
# 1086307  2021-12-22            5
# 1086315  2021-12-22            5
# 1086318  2021-12-22            5
# 1087030  2021-12-22            5
# 1087396  2021-12-22            5
# 1087428  2021-12-22            5
# 1087975  2021-12-22            5
# 1088250  2021-12-22            2
# 1091306  2021-12-22            5
# 1094269  2021-12-22            2
# 1094633  2021-12-22            2
# 1095954  2021-12-22            2
# 1096523  2021-12-22            2
# 1165036  2021-12-22            9
# 1167323  2021-12-22            6
# 1167325  2021-12-22            6
# 1167327  2021-12-22            5
# dtype: int64

# %% [markdown]
# # Tramites totales

# %%
df_tramites_completo = pd.read_parquet('./data/tramita/full/tramites_completo.parquet')

# %%
df_tramites_completo.head()
# Out:
#    id_exp   dni     nif      fecha_alta_exp fecha_registro_exp  \
# 0   14891  <NA>  392544 2012-08-30 13:26:39                NaT
# 1   14891  <NA>  392544 2012-08-30 13:26:39                NaT
# 2   14891  <NA>  392544 2012-08-30 13:26:39                NaT
# 3   14891  <NA>  392544 2012-08-30 13:26:39                NaT
# 4   14891  <NA>  392544 2012-08-30 13:26:39                NaT
#
#   codine_provincia codine_municipio codine              municipio provincia  \
# 0               45              142  45142  Quintanar de la Orden    Toledo
# 1               45              142  45142  Quintanar de la Orden    Toledo
# 2               45              142  45142  Quintanar de la Orden    Toledo
# 3               45              142  45142  Quintanar de la Orden    Toledo
# 4               45              142  45142  Quintanar de la Orden    Toledo
#
#    ... siaci                            consejeria_proc  \
# 0  ...  SJSK  Consejeria de economia, empresas y empleo
# ...

# %%
df_tramites_completo[df_tramites_completo['id_exp']==1088250]
# Out:
#           id_exp   dni    nif      fecha_alta_exp fecha_registro_exp  \
# 6265960  1088250  <NA>  50977 2022-02-07 09:50:23         2021-12-22
# 6265961  1088250  <NA>  50977 2022-02-07 09:50:23         2021-12-22
#
#         codine_provincia codine_municipio codine    municipio    provincia  \
# 6265960               13              034  13034  Ciudad Real  Ciudad Real
# 6265961               13              034  13034  Ciudad Real  Ciudad Real
#
#          ... siaci                      consejeria_proc  \
# 6265960  ...  SLPT  Consejeria de desarrollo sostenible
# 6265961  ...  SLPT  Consejeria de desarrollo sostenible
#
#                                 org_instructor_proc es_telematica  \
# 6265960  Direccion general de transicion energetica          True
# 6265961  Direccion general de transicion energetica          True
#
#                              desc_tramite       fecha_tramite num_tramite  \
# 6265960             Registro de solicitud 2021-12-22 00:00:00           0
# ...

# %% [markdown]
# # Tramites & Expedientes totales brutos

# %%
df_tramites_completo_c = pd.read_parquet('./data/tramita/full/TramitaGlobal-GB_ACTIVITIES_TRAMITES.parquet')

# %%
df_tramites_completo_c.head()
# Out:
#        _CASE_ID  NPROCADMI                                       _ACTIVITY_ES  \
# Index
# 0           3.0        1.0                9-1-Comunicación de la Contratación
# 1           3.0        1.0                   1-1-Presentación de la solicitud
# 2           3.0        1.0                       30-1-Evaluación de Solicitud
# 3           3.0        1.0  41-1-Propuesta Resolución Desfavorable Provisi...
# 4           3.0        1.0                          25-1-Tramite de Audiencia
#
#                 _EVENTIME   FECHA_FIN_TRAMITE FECHA_ANULACION_TRAMITE  \
# Index
# 0     2009-06-29 10:17:24 2009-06-29 10:17:24                     NaT
# 1     2010-02-12 10:35:44 2010-02-12 10:42:25                     NaT
# 2     2010-02-12 10:43:03 2010-02-12 10:45:35                     NaT
# 3     2010-02-12 10:46:24 2010-02-12 10:48:44                     NaT
# 4     2010-02-12 10:50:16 2010-02-23 10:25:33                     NaT
#
# ...

# %%
df_tramites_completo_c[df_tramites_completo_c['_CASE_ID']==1853399]
# Out:
#           _CASE_ID  NPROCADMI                      _ACTIVITY_ES  \
# Index
# 8554345  1853399.0      884.0             Registro de solicitud
# 8554346  1853399.0      884.0  1-1-Presentación de la solicitud
#
#                   _EVENTIME FECHA_FIN_TRAMITE FECHA_ANULACION_TRAMITE  \
# Index
# 8554345 2023-12-01 00:00:00               NaT                     NaT
# 8554346 2024-02-22 12:55:09               NaT                     NaT
#
#         FECHA_ENVIO_TRAMITE  _SORTING  IMPORTE_SOLICITADO  IMPORTE_APROBADO  \
# Index
# 8554345                 NaT       0.0                 NaN               NaN
# 8554346 2024-02-22 12:55:09       1.0                 NaN               NaN
#
#          IMPORTE_PAGADO USER_NAME USER_TYPE  NTRAMITE  NSECUENCI CINICIAL  \
# Index
# 8554345             NaN      None      None       0.0        0.0     None
# 8554346             NaN      None      None       1.0        1.0        S
#
#            _CELONIS_CHANGE_DATE
# Index
# ...

# %%
df_tramites_completo_c[df_tramites_completo_c['_CASE_ID']==1084489]
# Out:
#           _CASE_ID  NPROCADMI  \
# Index
# 5407599  1084489.0      884.0
# 5407600  1084489.0      884.0
# 5407601  1084489.0      884.0
# 5407602  1084489.0      884.0
# 5407603  1084489.0      884.0
# 5407604  1084489.0      884.0
# 5407605  1084489.0      884.0
# 5407606  1084489.0      884.0
# 5407607  1084489.0      884.0
#
#                                               _ACTIVITY_ES  \
# Index
# 5407599                              Registro de solicitud
# 5407600                   1-1-Presentación de la solicitud
# 5407601                       30-1-Evaluación de Solicitud
# 5407602  42-1-Propuesta Resolución Estimatoria de Conce...
# 5407603                       50-1-Resolución de Concesión
# 5407604      70-1-Presentación Documentación Justificativa
# 5407605                   30-2-Evaluación de justificación
# 5407606                                    82-1-Pago Total
# 5407607                                  287-1-Seguimiento
#
# ...

# %%
df_exp_completo_c = pd.read_parquet('./data/tramita/full/TramitaGlobal-GB_CASE_EXPEDIENTES.parquet')

# %%
df_exp_completo_c.head()
# Out:
#        _CASE_KEY              CODESPEC  NPROVINCI  NMUNICIPI  \
# Index
# 0        14891.0        EMPR-TO/047/12       45.0      142.0
# 1        14906.0  RGC/CP/TO/2012/01015       45.0      165.0
# 2        14915.0  RGC/CP/TO/2012/01021       45.0      168.0
# 3        14916.0  RGC/CP/AB/2012/01022        2.0       72.0
# 4        14917.0  RGC/CP/TO/2012/01023       35.0       22.0
#
#                  FECHALTA  NORGANO  NPROCADMI  NHAGRUPPE  NIDPJH  NIDREPREPJ  \
# Index
# 0     2012-08-30 13:26:39      6.0       34.0        NaN     NaN         NaN
# 1     2012-08-31 11:03:11     15.0       11.0        NaN     NaN         NaN
# 2     2012-08-31 12:47:29     15.0       11.0        NaN     NaN         NaN
# 3     2012-08-31 13:05:37     11.0       11.0        NaN     NaN         NaN
# 4     2012-08-31 13:18:10     15.0       11.0        NaN     NaN         NaN
#
#           NIDPF     NIDPJ    _CELONIS_CHANGE_DATE FREGISTRO FENVIO
# Index
# ...

# %%
df_exp_completo_c[df_exp_completo_c['_CASE_KEY']==1083865]
# Out:
#         _CASE_KEY         CODESPEC  NPROVINCI  NMUNICIPI            FECHALTA  \
# Index
# 693929  1083865.0  SLPT-2022-00003       13.0       64.0 2022-02-04 12:38:09
#
#         NORGANO  NPROCADMI  NHAGRUPPE  NIDPJH  NIDREPREPJ      NIDPF  NIDPJ  \
# Index
# 693929      NaN      884.0        NaN     NaN         NaN  1065227.0    NaN
#
#           _CELONIS_CHANGE_DATE  FREGISTRO     FENVIO
# Index
# 693929 2024-08-27 02:07:06.747 2021-12-22 2022-02-04

# %%
df_exp_completo_c[df_exp_completo_c['_CASE_KEY']==1084489]
# Out:
#          _CASE_KEY         CODESPEC  NPROVINCI  NMUNICIPI            FECHALTA  \
# Index
# 1142660  1084489.0  SLPT-2022-00026       45.0      163.0 2022-02-04 14:05:05
#
#          NORGANO  NPROCADMI  NHAGRUPPE  NIDPJH  NIDREPREPJ     NIDPF  NIDPJ  \
# Index
# 1142660      NaN      884.0        NaN     NaN         NaN  431645.0    NaN
#
#            _CELONIS_CHANGE_DATE  FREGISTRO     FENVIO
# Index
# 1142660 2024-08-27 02:07:06.747 2021-12-22 2022-02-04

# %% [markdown]
# # Solicitudes

# %%
df_solicitudes = pd.read_parquet('./data/tramita/full/TramitaGlobal-VW_SOLICITUDES_VENTANILLA.parquet')
df_solicitudes
# Out:
#           NRGESOLI  NIDPROCED               CIDSOLICI     CREGISTRO  \
# Index
# 0              2.0   116000.0                 7633000       1958356
# 1             29.0   116000.0                 7623700       1938842
# 2             38.0    41000.0                 7617700       1925551
# 3             52.0   116000.0                 7617300       1925595
# 4             61.0   116000.0                 7609300       1910929
# ...            ...        ...                     ...           ...
# 1383896  1508093.0    21605.0            TRAM_1987347       2898964
# 1383897  1508129.0  1111001.0  48150833B_172163134520  2933923/2024
# 1383898  1508152.0    39000.0            TRAM_1987489       1883124
# 1383899  1508161.0  1105000.0            TRAM_1987497         19996
# 1383900  1508180.0  1105000.0            TRAM_1987527         33242
#
#                   FREGISTRO  NEXPEDTRAM              FENVIO CMODOPRE  \
# Index
# ...

# %%
df_solicitudes[df_solicitudes['NEXPEDTRAM']==1853399]
# Out:
#          NRGESOLI  NIDPROCED                 CIDSOLICI     CREGISTRO  \
# Index
# 202811  1370340.0   884001.0  52116220Z_170141837641D1  4663690/2023
#
#                  FREGISTRO  NEXPEDTRAM              FENVIO CMODOPRE  \
# Index
# 202811 2023-12-01 09:41:29   1853399.0 2024-02-22 12:55:09        C
#
#           _CELONIS_CHANGE_DATE
# Index
# 202811 2024-08-27 02:09:16.496

# %%
len(df_solicitudes[(df_solicitudes['NIDPROCED']==884001) &
(df_solicitudes['CMODOPRE']=='P')])
# Out:
# 46

# %%
len(df_solicitudes[(df_solicitudes['NIDPROCED']==884001)])
# Out:
# 25845
